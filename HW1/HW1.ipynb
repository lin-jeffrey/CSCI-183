# %% [markdown]
# ## Homework 1
# *For any questions or concerns please email your instructor at `smanna@scu.edu`*
# ### Due - 01/24/2020 - 11:59p - 20 points
#
# **Name:** `<Jeffrey Lin>`
#
# **Email** `<jlin7@scu.edu>`
#
# **Objectives:** The main aim of this homework is to make you conversant with *exploratory data analysis (EDA)*.
#
# **Problem Statement** - You are given a wine dataset, which has different composition of chemicals that constitute white wine. Your task is to understand the dataset and answer the questions with respect to the dataset.
#
# *NOTE* - Please feel free to use the *w2-AnalyzingData.ipynb* as a reference to work on this homework. You will find this in Camino under `Files` $\rightarrow$ `notebook`$\rightarrow$ `w2-AnalyzingData.ipynb`.
#
# **Submission Instructions:**
# * Please download `HW1.ipynb` and `winequality.csv` files and insert cells in the `HW1.ipynb` to complete your homework and submit the same file to Camino under `Homework` $\rightarrow$ `HW1`.
#
# **Honor Code:** You are expected to complete the homework on your own. Solutions might exist elsewhere, but you are not allowed to copy them.

# %%
# import different libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns # you would need if you work on the optional part of this homework

# %matplotlib inline

# %% [markdown]
# **Question 1 (2 pts)**

# %%
# read the input file into a dataframe, and name it 'white_wine'
# TODO
white_wine = pd.read_csv("winequality.csv")
# print the dataframe
# TODO
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# **Question 2 (5 pts)**

# %%
# print how many data points are there in the dataset along with their features
# TODO
white_wine.shape[0]
# Out:
# 4898

# %%
# print detailed information about the features of your dataset
# TODO
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# print first 20 rows 
# TODO
white_wine.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# ...

# %%
# print middle 20 rows
# TODO
white_wine.iloc[4888:4908]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# print last 20 rows
# TODO
white_wine.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4878            6.2             0.530         0.02            0.90      0.035
# 4879            6.6             0.340         0.40            8.10      0.046
# 4880            6.6             0.340         0.40            8.10      0.046
# 4881            5.0             0.235         0.27           11.75      0.030
# 4882            5.5             0.320         0.13            1.30      0.037
# 4883            4.9             0.470         0.17            1.90      0.035
# 4884            6.5             0.330         0.38            8.30      0.048
# 4885            6.6             0.340         0.40            8.10      0.046
# 4886            6.2             0.210         0.28            5.70      0.028
# 4887            6.2             0.410         0.22            1.90      0.023
# 4888            6.8             0.220         0.36            1.20      0.052
# ...

# %% [markdown]
# **Question 3 (3 pts)**

# %%
# find out how many data points are there 
# whose alcohol level is greater than 10 and sulphate quantity is greater than 0.50

# TODO
ha = white_wine[(white_wine['alcohol']>10)&(white_wine['sulphates']>0.50)]
ha.shape[0]
# Out:
# 1117

# %% [markdown]
# **Question 4 (2 pts)**

# %%
# find out if there is any null value in the dataframe
# TODO
white_wine.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Question 5 (2 pts)**

# %%
# print number of occurrences of sulphates' value in the white_wine
# TODO
#white_wine.groupby(['sulphates']).size()
white_wine['sulphates'].value_counts()
# Out:
# 0.50    249
# 0.46    225
# 0.44    216
# 0.38    214
# 0.42    181
# 0.48    179
# 0.45    178
# 0.47    172
# 0.40    168
# 0.54    167
# 0.49    166
# 0.43    161
# 0.52    156
# 0.39    151
# 0.51    140
# 0.41    139
# 0.53    135
# 0.37    129
# 0.36    120
# 0.56    108
# 0.55    102
# 0.58     99
# 0.59     97
# 0.60     88
# 0.35     85
# 0.34     84
# 0.57     83
# 0.62     68
# 0.64     67
# 0.33     59
#        ...
# 0.29     16
# 0.28     13
# 0.82     13
# 0.27     13
# 0.73     12
# 0.88      7
# 0.98      6
# 0.80      5
# 0.90      5
# 0.95      5
# 0.81      5
# 0.25      4
# 0.84      4
# 0.26      4
# 0.85      3
# 0.96      3
# 0.83      2
# 0.86      2
# 0.94      2
# 0.87      2
# 0.92      2
# 1.08      1
# 1.00      1
# 0.97      1
# 1.01      1
# 0.89      1
# 1.06      1
# 0.22      1
# 0.23      1
# 0.99      1
# Name: sulphates, Length: 79, dtype: int64

# %% [markdown]
# **Question 6 (3 pts)**

# %%
# create a subset of attributes - 'residual sugar', 'total sulfur dioxide', 'sulphates', 'alcohol', 'volatile acidity', 'quality'
# TODO
white_wine[['residual sugar', 'total sulfur dioxide', 'sulphates', 'alcohol', 'volatile acidity', 'quality']].head()
# Out:
#    residual sugar  total sulfur dioxide  sulphates  alcohol  volatile acidity  \
# 0            20.7                 170.0       0.45      8.8              0.27
# 1             1.6                 132.0       0.49      9.5              0.30
# 2             6.9                  97.0       0.44     10.1              0.28
# 3             8.5                 186.0       0.40      9.9              0.23
# 4             8.5                 186.0       0.40      9.9              0.23
#
#    quality
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6

# %% [markdown]
# **Question 7 (3 pts)**

# %%
# create a new dataframe with the subset of attributes and compute the basic statistics
# TODO
sub_white_wine = white_wine[['residual sugar', 'total sulfur dioxide', 'sulphates', 'alcohol', 'volatile acidity', 'quality']]
sub_white_wine.describe()
# print the newly formed dataframe
# TODO
sub_white_wine.head(sub_white_wine.shape[0])
# Out:
#       residual sugar  total sulfur dioxide  sulphates    alcohol  \
# 0              20.70                 170.0       0.45   8.800000
# 1               1.60                 132.0       0.49   9.500000
# 2               6.90                  97.0       0.44  10.100000
# 3               8.50                 186.0       0.40   9.900000
# 4               8.50                 186.0       0.40   9.900000
# 5               6.90                  97.0       0.44  10.100000
# 6               7.00                 136.0       0.47   9.600000
# 7              20.70                 170.0       0.45   8.800000
# 8               1.60                 132.0       0.49   9.500000
# 9               1.50                 129.0       0.45  11.000000
# 10              1.45                  63.0       0.56  12.000000
# 11              4.20                 109.0       0.53   9.700000
# 12              1.20                  75.0       0.63  10.800000
# ...

# %% [markdown]
# ### Optional (extra credit)
# **Part 1 (2 points)** For this part of this homework, you can use pandas hist function. More details can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html).

# %%
# Plot histograms for all the features in the white_wine 
# Feel free to choose your color
# Make sure your labels are properly printed
# You are required to look at 'hist' function of dataframe and use help
# you can alternatively use matplotlib's functions

# TODO

# %% [markdown]
# **Part 2 (2 points)**
# For this part of this homework, you have to use seaborn library. Please refer to [this](https://seaborn.pydata.org/generated/seaborn.heatmap.html) documentation as your reference.

# %%
# Compute correlation function on your dataframe
# use the correlation to draw a heatmap using seaborn library
# you are required to do little research to find out how would you complete this task
# make sure the correlation values are provided in the heatmap
# you can choose whatever color theme you would like
# also make sure you have a legend!

# TODO
